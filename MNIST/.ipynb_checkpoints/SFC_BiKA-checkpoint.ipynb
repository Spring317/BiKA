# %%
import os
import random
import shutil
import itertools
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import pwlf
from multiprocessing import Pool, cpu_count
from tqdm import tqdm, trange

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

import brevitas.nn as qnn
from brevitas.nn import QuantLinear, QuantReLU, QuantConv2d
from brevitas.quant.binary import SignedBinaryActPerTensorConst
from brevitas.quant.binary import SignedBinaryWeightPerTensorConst
from brevitas.inject.enum import QuantType
from brevitas.quant_tensor.int_quant_tensor import IntQuantTensor
from brevitas.function.ops_ste import round_ste

from bika import BiKA_Linear, BiKA_Conv2d

GPU_device = "cuda:1"

# %% [markdown]
# # Network Definition

# %%
input_length = 28*28
hidden_0 = 256
hidden_1 = 256
hidden_2 = 256
output_length = 10

# %%
class MLP(nn.Module):
    def __init__(self, dropout=0.5):
        super(MLP, self).__init__()
        
        self.fc0   = BiKA_Linear(in_features=input_length, out_features=hidden_0)
        self.drop0 = nn.Dropout(dropout)
        
        self.fc1   = BiKA_Linear(in_features=hidden_0, out_features=hidden_1)
        self.drop1 = nn.Dropout(dropout)
        
        self.fc2   = BiKA_Linear(in_features=hidden_1, out_features=hidden_2)
        self.drop2 = nn.Dropout(dropout)
        
        self.out   = BiKA_Linear(in_features=hidden_2, out_features=output_length)

    def forward(self, x):
        
        out = x.reshape(x.shape[0], -1)
        
        out = self.drop0(self.fc0(out))
        out = self.drop1(self.fc1(out))
        out = self.drop2(self.fc2(out))
        out = self.out(out)
        
        return out

# %% [markdown]
# # Random Seed Utility

# %%
def set_random_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# # Define Dataloader

# %%
Test_batch_size = 4096

# %%
def get_dataloaders(batch_size):
    try:
        # Works if running as a .py script
        project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), ".."))
    except NameError:
        # Works if running in Jupyter (no __file__)
        project_root = os.path.abspath("..")
    
    dataset_root = os.path.join(project_root, "Dataset")
    
    train_dataset = datasets.MNIST(  dataset_root, 
                                     train=True, 
                                     download=True,
                                     transform=transforms.Compose
                                     ([
                                         transforms.ToTensor(),
                                         transforms.Normalize((0.5,), (0.5,))
                                     ])
                                  )
    test_dataset  = datasets.MNIST( dataset_root, 
                                    train=False, 
                                    download=True,
                                    transform=transforms.Compose
                                    ([
                                         transforms.ToTensor(),
                                         transforms.Normalize((0.5,), (0.5,))
                                    ])
                                  )
    val_size = int(0.2 * len(train_dataset))
    train_size = len(train_dataset) - val_size
    train_set, val_set = random_split(train_dataset, [train_size, val_size])
    return (
        DataLoader(train_set, batch_size=batch_size, shuffle=True),
        DataLoader(val_set, batch_size=batch_size),
        DataLoader(test_dataset, batch_size=batch_size),
    )

# %% [markdown]
# # Evaluation Pipeline

# %%
def evaluate(model, criterion, device, loader, train):
    model.eval()
    loss_total, correct, total = 0, 0, 0
    with torch.no_grad():
        if (train):
            for x, y in loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                loss_total += loss.item() * x.size(0)
                _, pred = out.max(1)
                correct += (pred == y).sum().item()
                total += x.size(0)
        else:
            for x, y in tqdm(loader, desc="Evaluation", leave=True):
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = criterion(out, y)
                loss_total += loss.item() * x.size(0)
                _, pred = out.max(1)
                correct += (pred == y).sum().item()
                total += x.size(0)
    return loss_total / total, correct / total

# %% [markdown]
# # Plot Training Loss and Accuracy

# %%
def plot_train(history, save_dir):
    # Plot and show
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history["train_loss"], label="Train Loss")
    plt.plot(history["val_loss"], label="Val Loss")
    plt.legend()
    plt.title("Loss")

    plt.subplot(1, 2, 2)
    plt.plot(history["train_acc"], label="Train Acc")
    plt.plot(history["val_acc"], label="Val Acc")
    plt.legend()
    plt.title("Accuracy")
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "training_plot.png"))
    plt.show()

# %% [markdown]
# # Training, Validation, and Testing Pipeline

# %%
def train_validate_test(config, save_dir):
    set_random_seed()
    os.makedirs(save_dir, exist_ok=True)
    log_file = os.path.join(save_dir, "training_log.txt")
    resume_path = os.path.join(save_dir, "checkpoint.pth")

    epochs, batch_size, lr1, lr2, lr3, dropout = config
    train_loader, val_loader, test_loader = get_dataloaders(batch_size)
    device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
    model = MLP(dropout=dropout).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr1)

    start_epoch = 0
    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    if os.path.exists(resume_path):
        ckpt = torch.load(resume_path)
        model.load_state_dict(ckpt["model_state"])
        model.to(device)
        optimizer.load_state_dict(ckpt["optimizer_state"])
        history = ckpt["history"]
        start_epoch = ckpt["epoch"] + 1
        print(f"🔄 Resuming from epoch {start_epoch}")
    else:
        with open(log_file, "w") as f:
            f.write("Training started\n")

    # Training Loop
    t = trange(start_epoch, epochs, desc="Training", leave=True)
    for epoch in t:
        model.train()
        lr = lr1 if epoch < 0.5 * epochs else lr2 if epoch < 0.8 * epochs else lr3
        for g in optimizer.param_groups:
            g["lr"] = lr

        train_loss, correct, total = 0, 0, 0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * x.size(0)
            _, pred = out.max(1)
            correct += (pred == y).sum().item()
            total += x.size(0)

        val_loss, val_acc = evaluate(model, criterion, device, val_loader, train=True)
        train_loss /= total
        train_acc = correct / total
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        log_line = (f"Epoch {epoch+1}/{epochs} - LR: {lr:.5f} | "
                    f"Train Loss: {train_loss:.4f}, Acc: {train_acc:.4f} | "
                    f"Val Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")
        #print(log_line)
        with open(log_file, "a") as f:
            f.write(log_line + "\n")

        t.set_description("| LR: %.3f | Train Acc: %.4f | Val Acc: %.4f |" % (lr, train_acc, val_acc))
        t.refresh()

        torch.save({
            "epoch": epoch,
            "model_state": model.state_dict(),
            "optimizer_state": optimizer.state_dict(),
            "history": history
        }, resume_path)

    # Plot and show the training history
    plot_train(history, save_dir)

    # Test the original trained model
    original_test_loss, original_test_acc = evaluate(model, criterion, device, test_loader, train=False)
    final_line = f"Original Model Final Test Loss: {original_test_loss:.4f} Accuracy: {original_test_acc:.4f}"
    print(final_line)
    with open(log_file, "a") as f:
        f.write("Training completed\n")
        f.write(final_line + "\n")

    # Save the trained model
    torch.save(model.state_dict(), os.path.join(save_dir, "final_model.pth"))
    with open(log_file, "a") as f:
        f.write(final_line + "\n")
    print("\n")

    return original_test_acc

# %% [markdown]
# # Hyperparameter Searching for Network Training and Testing

# %%
def Hyperparameter_searching(root_path, epochs, batch_sizes, lr_pool, dropout_rates):
    output_root = root_path
    os.makedirs(output_root, exist_ok=True)
    
    epochs = epochs
    batch_sizes = batch_sizes
    lr_pool = lr_pool
    
    # Generate descending LR combinations
    lr_combos = [combo for combo in itertools.product(lr_pool, repeat=3)
                 if (combo[0] > combo[1] > combo[2]) or (combo[0] == combo[1] == combo[2])]
    
    all_runs = [
        f"batch{bs}_lr{lr1}_{lr2}_{lr3}"
        for bs, (lr1, lr2, lr3) in itertools.product(batch_sizes, lr_combos)
    ]
    
    completed_runs = []
    for run in all_runs:
        log_path = os.path.join(output_root, run, "training_log.txt")
        if os.path.exists(log_path):
            with open(log_path, "r") as f:
                if any("Training completed" in line for line in f):
                    completed_runs.append(run)
    
    if len(completed_runs) == len(all_runs):
        print("✅ All combinations completed. Restarting from scratch...")
        for run in all_runs:
            shutil.rmtree(os.path.join(output_root, run), ignore_errors=True)
        if os.path.exists(os.path.join(output_root, "summary.csv")):
            os.remove(os.path.join(output_root, "summary.csv"))
        completed_runs = []
    
    results = []
    for batch_size, (lr1, lr2, lr3), dropout in itertools.product(batch_sizes, lr_combos, dropout_rates):
        run_name = f"batch{batch_size}_lr{lr1}_{lr2}_{lr3}_dp{dropout}"
        save_dir = os.path.join(output_root, run_name)
    
        if run_name in completed_runs:
            print(f"✅ Skipping {run_name}")
            with open(os.path.join(save_dir, "training_log.txt")) as f:
                for line in f:
                    if "Final Test Loss" in line:
                        acc = float(line.strip().split()[-1])
                        results.append((run_name, acc))
            continue
    
        print(f"🚀 Running: {run_name}")
        acc = train_validate_test([epochs, batch_size, lr1, lr2, lr3, dropout], save_dir)
        results.append((run_name, acc))
    
    results.sort(key=lambda x: x[1], reverse=True)
    best_config, best_acc = results[0]
    print(f"🏆 Best Config: {best_config} Accuracy: {best_acc:.4f}")
    
    with open(os.path.join(output_root, "summary.csv"), "w") as f:
        f.write("Config,Accuracy\n")
        for name, acc in results:
            f.write(f"{name},{acc:.4f}\n")

# %%
root_path = "SFC_BiKA"
epochs = 200
batch_sizes = [256, 512, 1024]
dropout_rates = [0.0, 0.2, 0.5]
lr_pool = [0.0010, 0.0005, 0.0002, 0.0001]

Hyperparameter_searching(root_path, epochs, batch_sizes, lr_pool, dropout_rates)
# Out:
# 🚀 Running: batch256_lr0.001_0.001_0.001_dp0.0
# 🔄 Resuming from epoch 10
# Training: 0it [00:00, ?it/s]
# Evaluation: 100%|███████████████████████████████| 40/40 [00:01<00:00, 31.35it/s]
# Original Model Final Test Loss: 1.8265 Accuracy: 0.8948
# 🏆 Best Config: batch256_lr0.001_0.001_0.001_dp0.0 Accuracy: 0.8948
# | LR: 0.010 | Train Acc: 0.9802 | Val Acc: 0.9723 |:   5%|▌         | 5/100 [00:39<10:05,  6.37s/it]
# | LR: 0.010 | Train Acc: 0.9802 | Val Acc: 0.9723 |:   6%|▌         | 6/100 [00:39<09:58,  6.37s/it]
# | LR: 0.010 | Train Acc: 0.9810 | Val Acc: 0.9718 |:   6%|▌         | 6/100 [00:45<09:58,  6.37s/it]
/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9799 |:  89%|████████▉ | 89/100 [09:38<01:10,  6.43s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9804 |:  89%|████████▉ | 89/100 [09:45<01:10,  6.43s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9804 |:  89%|████████▉ | 89/100 [09:45<01:10,  6.43s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9804 |:  90%|█████████ | 90/100 [09:45<01:05,  6.50s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9808 |:  90%|█████████ | 90/100 [09:51<01:05,  6.50s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9808 |:  90%|█████████ | 90/100 [09:51<01:05,  6.50s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9808 |:  91%|█████████ | 91/100 [09:51<00:58,  6.50s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9805 |:  91%|█████████ | 91/100 [09:58<00:58,  6.50s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9805 |:  91%|█████████ | 91/100 [09:58<00:58,  6.50s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9805 |:  92%|█████████▏| 92/100 [09:58<00:51,  6.41s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9812 |:  92%|█████████▏| 92/100 [10:04<00:51,  6.41s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9812 |:  92%|█████████▏| 92/100 [10:04<00:51,  6.41s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9812 |:  93%|█████████▎| 93/100 [10:04<00:44,  6.42s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9815 |:  93%|█████████▎| 93/100 [10:10<00:44,  6.42s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9815 |:  93%|█████████▎| 93/100 [10:10<00:44,  6.42s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9815 |:  94%|█████████▍| 94/100 [10:10<00:38,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9811 |:  94%|█████████▍| 94/100 [10:17<00:38,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9811 |:  94%|█████████▍| 94/100 [10:17<00:38,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9992 | Val Acc: 0.9811 |:  95%|█████████▌| 95/100 [10:17<00:31,  6.38s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9808 |:  95%|█████████▌| 95/100 [10:23<00:31,  6.38s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9808 |:  95%|█████████▌| 95/100 [10:23<00:31,  6.38s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9808 |:  96%|█████████▌| 96/100 [10:23<00:25,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9798 |:  96%|█████████▌| 96/100 [10:29<00:25,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9798 |:  96%|█████████▌| 96/100 [10:29<00:25,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9994 | Val Acc: 0.9798 |:  97%|█████████▋| 97/100 [10:29<00:19,  6.33s/it]
# | LR: 0.001 | Train Acc: 0.9995 | Val Acc: 0.9803 |:  97%|█████████▋| 97/100 [10:36<00:19,  6.33s/it]
# | LR: 0.001 | Train Acc: 0.9995 | Val Acc: 0.9803 |:  97%|█████████▋| 97/100 [10:36<00:19,  6.33s/it]
# | LR: 0.001 | Train Acc: 0.9995 | Val Acc: 0.9803 |:  98%|█████████▊| 98/100 [10:36<00:12,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9995 | Val Acc: 0.9800 |:  98%|█████████▊| 98/100 [10:42<00:12,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9995 | Val Acc: 0.9800 |:  98%|█████████▊| 98/100 [10:42<00:12,  6.37s/it]
# | LR: 0.001 | Train Acc: 0.9995 | Val Acc: 0.9800 |:  99%|█████████▉| 99/100 [10:42<00:06,  6.40s/it]
# | LR: 0.001 | Train Acc: 0.9993 | Val Acc: 0.9808 |:  99%|█████████▉| 99/100 [10:49<00:06,  6.40s/it]
# | LR: 0.001 | Train Acc: 0.9993 | Val Acc: 0.9808 |:  99%|█████████▉| 99/100 [10:49<00:06,  6.40s/it]
# | LR: 0.001 | Train Acc: 0.9993 | Val Acc: 0.9808 |: 100%|██████████| 100/100 [10:49<00:00,  6.38s/it]
# | LR: 0.001 | Train Acc: 0.9993 | Val Acc: 0.9808 |: 100%|██████████| 100/100 [10:49<00:00,  6.49s/it]
# Original Model Final Test Loss: 0.1129 Accuracy: 0.9823
# Fitting the PWL functions for fc0:   0%|          | 0/256 [00:00<?, ?it/s]
# Fitting the PWL functions for fc0:   0%|          | 0/256 [00:09<?, ?it/s]
# Fitting the PWL functions for fc0:   0%|          | 0/256 [00:09<?, ?it/s]
# Fitting the PWL functions for fc0:   0%|          | 1/256 [00:09<38:33,  9.07s/it]
# Fitting the PWL functions for fc0:   0%|          | 1/256 [00:23<38:33,  9.07s/it]
# Fitting the PWL functions for fc0:   0%|          | 1/256 [00:23<38:33,  9.07s/it]
# Fitting the PWL functions for fc0:   1%|          | 2/256 [00:23<52:53, 12.49s/it]
# Fitting the PWL functions for fc0:   1%|          | 2/256 [00:46<52:53, 12.49s/it]
# Fitting the PWL functions for fc0:   1%|          | 2/256 [00:46<52:53, 12.49s/it]
# Fitting the PWL functions for fc0:   1%|          | 3/256 [00:46<1:11:43, 17.01s/it]
# Fitting the PWL functions for fc0:   1%|          | 3/256 [01:03<1:11:43, 17.01s/it]
# Fitting the PWL functions for fc0:   1%|          | 3/256 [01:03<1:11:43, 17.01s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 4/256 [01:03<1:11:29, 17.02s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 4/256 [01:27<1:11:29, 17.02s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 4/256 [01:27<1:11:29, 17.02s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 5/256 [01:27<1:21:30, 19.49s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 5/256 [01:41<1:21:30, 19.49s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 5/256 [01:41<1:21:30, 19.49s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 6/256 [01:41<1:13:44, 17.70s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 6/256 [01:59<1:13:44, 17.70s/it]
# Fitting the PWL functions for fc0:   2%|▏         | 6/256 [01:59<1:13:44, 17.70s/it]
# Fitting the PWL functions for fc0:   3%|▎         | 7/256 [01:59<1:13:15, 17.65s/it]
# Fitting the PWL functions for fc0:   3%|▎         | 7/256 [02:14<1:13:15, 17.65s/it]
# Fitting the PWL functions for fc0:   3%|▎         | 7/256 [02:14<1:13:15, 17.65s/it]
# Fitting the PWL functions for fc0:   3%|▎         | 8/256 [02:14<1:10:05, 16.96s/it]
# Fitting the PWL functions for fc0:   3%|▎         | 8/256 [02:28<1:10:05, 16.96s/it]
# Fitting the PWL functions for fc0:   3%|▎         | 8/256 [02:28<1:10:05, 16.96s/it]
# Fitting the PWL functions for fc0:   4%|▎         | 9/256 [02:28<1:06:01, 16.04s/it]
# Fitting the PWL functions for fc0:   4%|▎         | 9/256 [02:42<1:06:01, 16.04s/it]
# Fitting the PWL functions for fc0:   4%|▎         | 9/256 [02:42<1:06:01, 16.04s/it]
# Fitting the PWL functions for fc0:   4%|▍         | 10/256 [02:42<1:03:41, 15.54s/it]
# Fitting the PWL functions for fc0:   4%|▍         | 10/256 [03:06<1:03:41, 15.54s/it]
# Fitting the PWL functions for fc0:   4%|▍         | 10/256 [03:06<1:03:41, 15.54s/it]
# Fitting the PWL functions for fc0:   4%|▍         | 11/256 [03:06<1:13:38, 18.04s/it]
# Fitting the PWL functions for fc0:   4%|▍         | 11/256 [03:27<1:13:38, 18.04s/it]
# Fitting the PWL functions for fc0:   4%|▍         | 11/256 [03:27<1:13:38, 18.04s/it]
# Fitting the PWL functions for fc0:   5%|▍         | 12/256 [03:27<1:16:25, 18.79s/it]
# Fitting the PWL functions for fc0:   5%|▍         | 12/256 [03:43<1:16:25, 18.79s/it]
# Fitting the PWL functions for fc0:   5%|▍         | 12/256 [03:43<1:16:25, 18.79s/it]
# Fitting the PWL functions for fc0:   5%|▌         | 13/256 [03:43<1:13:18, 18.10s/it]
# Fitting the PWL functions for fc0:   5%|▌         | 13/256 [04:02<1:13:18, 18.10s/it]
# Fitting the PWL functions for fc0:   5%|▌         | 13/256 [04:02<1:13:18, 18.10s/it]
# Fitting the PWL functions for fc0:   5%|▌         | 14/256 [04:02<1:14:20, 18.43s/it]
# Fitting the PWL functions for fc0:   5%|▌         | 14/256 [04:18<1:14:20, 18.43s/it]
# Fitting the PWL functions for fc0:   5%|▌         | 14/256 [04:18<1:14:20, 18.43s/it]
# Fitting the PWL functions for fc0:   6%|▌         | 15/256 [04:18<1:10:35, 17.57s/it]
# Fitting the PWL functions for fc0:   6%|▌         | 15/256 [04:34<1:10:35, 17.57s/it]
# Fitting the PWL functions for fc0:   6%|▌         | 15/256 [04:34<1:10:35, 17.57s/it]
# Fitting the PWL functions for fc0:   6%|▋         | 16/256 [04:34<1:07:54, 16.98s/it]
# Fitting the PWL functions for fc0:   6%|▋         | 16/256 [04:52<1:07:54, 16.98s/it]
# Fitting the PWL functions for fc0:   6%|▋         | 16/256 [04:52<1:07:54, 16.98s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 17/256 [04:52<1:09:00, 17.32s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 17/256 [05:32<1:09:00, 17.32s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 17/256 [05:32<1:09:00, 17.32s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 18/256 [05:32<1:36:08, 24.24s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 18/256 [05:45<1:36:08, 24.24s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 18/256 [05:45<1:36:08, 24.24s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 19/256 [05:45<1:22:53, 20.98s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 19/256 [05:59<1:22:53, 20.98s/it]
# Fitting the PWL functions for fc0:   7%|▋         | 19/256 [05:59<1:22:53, 20.98s/it]
# Fitting the PWL functions for fc0:   8%|▊         | 20/256 [05:59<1:13:41, 18.73s/it]
# Fitting the PWL functions for fc0:   8%|▊         | 20/256 [06:14<1:13:41, 18.73s/it]
# Fitting the PWL functions for fc0:   8%|▊         | 20/256 [06:14<1:13:41, 18.73s/it]
# Fitting the PWL functions for fc0:   8%|▊         | 21/256 [06:14<1:08:42, 17.54s/it]
# Fitting the PWL functions for fc0:   8%|▊         | 21/256 [06:26<1:08:42, 17.54s/it]
# Fitting the PWL functions for fc0:   8%|▊         | 21/256 [06:26<1:08:42, 17.54s/it]
# Fitting the PWL functions for fc0:   9%|▊         | 22/256 [06:26<1:02:28, 16.02s/it]
# Fitting the PWL functions for fc0:   9%|▊         | 22/256 [06:52<1:02:28, 16.02s/it]
# Fitting the PWL functions for fc0:   9%|▊         | 22/256 [06:52<1:02:28, 16.02s/it]
# Fitting the PWL functions for fc0:   9%|▉         | 23/256 [06:52<1:14:05, 19.08s/it]
# Fitting the PWL functions for fc0:   9%|▉         | 23/256 [07:01<1:14:05, 19.08s/it]
# Fitting the PWL functions for fc0:   9%|▉         | 23/256 [07:01<1:14:05, 19.08s/it]
# Fitting the PWL functions for fc0:   9%|▉         | 24/256 [07:01<1:01:48, 15.98s/it]
# Fitting the PWL functions for fc0:   9%|▉         | 24/256 [07:22<1:01:48, 15.98s/it]
# Fitting the PWL functions for fc0:   9%|▉         | 24/256 [07:22<1:01:48, 15.98s/it]
# Fitting the PWL functions for fc0:  10%|▉         | 25/256 [07:22<1:07:25, 17.51s/it]
# Fitting the PWL functions for fc0:  10%|▉         | 25/256 [07:45<1:07:25, 17.51s/it]
# Fitting the PWL functions for fc0:  10%|▉         | 25/256 [07:45<1:07:25, 17.51s/it]
# Fitting the PWL functions for fc0:  10%|█         | 26/256 [07:45<1:13:39, 19.22s/it]
# Fitting the PWL functions for fc0:  10%|█         | 26/256 [07:55<1:13:39, 19.22s/it]
# Fitting the PWL functions for fc0:  10%|█         | 26/256 [07:55<1:13:39, 19.22s/it]
# Fitting the PWL functions for fc0:  11%|█         | 27/256 [07:55<1:02:30, 16.38s/it]
# Fitting the PWL functions for fc0:  11%|█         | 27/256 [08:12<1:02:30, 16.38s/it]
# Fitting the PWL functions for fc0:  11%|█         | 27/256 [08:12<1:02:30, 16.38s/it]
# Fitting the PWL functions for fc0:  11%|█         | 28/256 [08:12<1:03:17, 16.66s/it]
# Fitting the PWL functions for fc0:  11%|█         | 28/256 [08:24<1:03:17, 16.66s/it]
# Fitting the PWL functions for fc0:  11%|█         | 28/256 [08:24<1:03:17, 16.66s/it]
# Fitting the PWL functions for fc0:  11%|█▏        | 29/256 [08:24<56:54, 15.04s/it]
# Fitting the PWL functions for fc0:  11%|█▏        | 29/256 [08:41<56:54, 15.04s/it]
# Fitting the PWL functions for fc0:  11%|█▏        | 29/256 [08:41<56:54, 15.04s/it]
# Fitting the PWL functions for fc0:  12%|█▏        | 30/256 [08:41<59:08, 15.70s/it]
# Fitting the PWL functions for fc0:  12%|█▏        | 30/256 [08:59<59:08, 15.70s/it]
# Fitting the PWL functions for fc0:  12%|█▏        | 30/256 [08:59<59:08, 15.70s/it]
# Fitting the PWL functions for fc0:  12%|█▏        | 31/256 [08:59<1:01:21, 16.36s/it]
# Fitting the PWL functions for fc0:  12%|█▏        | 31/256 [09:09<1:01:21, 16.36s/it]
# Fitting the PWL functions for fc0:  12%|█▏        | 31/256 [09:09<1:01:21, 16.36s/it]
# Fitting the PWL functions for fc0:  12%|█▎        | 32/256 [09:09<54:04, 14.49s/it]
# Fitting the PWL functions for fc0:  12%|█▎        | 32/256 [09:23<54:04, 14.49s/it]
# Fitting the PWL functions for fc0:  12%|█▎        | 32/256 [09:23<54:04, 14.49s/it]
# Fitting the PWL functions for fc0:  13%|█▎        | 33/256 [09:23<53:25, 14.37s/it]
# Fitting the PWL functions for fc0:  13%|█▎        | 33/256 [09:40<53:25, 14.37s/it]
# Fitting the PWL functions for fc0:  13%|█▎        | 33/256 [09:40<53:25, 14.37s/it]
# Fitting the PWL functions for fc0:  13%|█▎        | 34/256 [09:40<56:10, 15.18s/it]
# Fitting the PWL functions for fc0:  13%|█▎        | 34/256 [09:53<56:10, 15.18s/it]
# Fitting the PWL functions for fc0:  13%|█▎        | 34/256 [09:53<56:10, 15.18s/it]
# Fitting the PWL functions for fc0:  14%|█▎        | 35/256 [09:53<52:50, 14.34s/it]
# Fitting the PWL functions for fc0:  14%|█▎        | 35/256 [10:08<52:50, 14.34s/it]
# Fitting the PWL functions for fc0:  14%|█▎        | 35/256 [10:08<52:50, 14.34s/it]
# Fitting the PWL functions for fc0:  14%|█▍        | 36/256 [10:08<53:42, 14.65s/it]
# Fitting the PWL functions for fc0:  14%|█▍        | 36/256 [10:23<53:42, 14.65s/it]
# Fitting the PWL functions for fc0:  14%|█▍        | 36/256 [10:23<53:42, 14.65s/it]
# Fitting the PWL functions for fc0:  14%|█▍        | 37/256 [10:23<53:52, 14.76s/it]
# Fitting the PWL functions for fc0:  14%|█▍        | 37/256 [10:39<53:52, 14.76s/it]
# Fitting the PWL functions for fc0:  14%|█▍        | 37/256 [10:39<53:52, 14.76s/it]
# Fitting the PWL functions for fc0:  15%|█▍        | 38/256 [10:39<54:37, 15.03s/it]
# Fitting the PWL functions for fc0:  15%|█▍        | 38/256 [10:47<54:37, 15.03s/it]
# Fitting the PWL functions for fc0:  15%|█▍        | 38/256 [10:47<54:37, 15.03s/it]
# Fitting the PWL functions for fc0:  15%|█▌        | 39/256 [10:47<46:49, 12.95s/it]
# Fitting the PWL functions for fc0:  15%|█▌        | 39/256 [11:09<46:49, 12.95s/it]
# Fitting the PWL functions for fc0:  15%|█▌        | 39/256 [11:09<46:49, 12.95s/it]
# Fitting the PWL functions for fc0:  16%|█▌        | 40/256 [11:09<56:20, 15.65s/it]
# Fitting the PWL functions for fc0:  16%|█▌        | 40/256 [11:32<56:20, 15.65s/it]
# Fitting the PWL functions for fc0:  16%|█▌        | 40/256 [11:32<56:20, 15.65s/it]
# Fitting the PWL functions for fc0:  16%|█▌        | 41/256 [11:32<1:03:57, 17.85s/it]
# Fitting the PWL functions for fc0:  16%|█▌        | 41/256 [11:49<1:03:57, 17.85s/it]
# Fitting the PWL functions for fc0:  16%|█▌        | 41/256 [11:49<1:03:57, 17.85s/it]
# Fitting the PWL functions for fc0:  16%|█▋        | 42/256 [11:49<1:02:48, 17.61s/it]
# Fitting the PWL functions for fc0:  16%|█▋        | 42/256 [12:11<1:02:48, 17.61s/it]
# Fitting the PWL functions for fc0:  16%|█▋        | 42/256 [12:11<1:02:48, 17.61s/it]
# Fitting the PWL functions for fc0:  17%|█▋        | 43/256 [12:11<1:07:14, 18.94s/it]
# Fitting the PWL functions for fc0:  17%|█▋        | 43/256 [12:25<1:07:14, 18.94s/it]
# Fitting the PWL functions for fc0:  17%|█▋        | 43/256 [12:25<1:07:14, 18.94s/it]
# Fitting the PWL functions for fc0:  17%|█▋        | 44/256 [12:25<1:01:36, 17.44s/it]
# Fitting the PWL functions for fc0:  17%|█▋        | 44/256 [12:46<1:01:36, 17.44s/it]
# Fitting the PWL functions for fc0:  17%|█▋        | 44/256 [12:46<1:01:36, 17.44s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 45/256 [12:46<1:05:49, 18.72s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 45/256 [12:56<1:05:49, 18.72s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 45/256 [12:56<1:05:49, 18.72s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 46/256 [12:56<55:47, 15.94s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 46/256 [13:08<55:47, 15.94s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 46/256 [13:08<55:47, 15.94s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 47/256 [13:08<51:31, 14.79s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 47/256 [13:23<51:31, 14.79s/it]
# Fitting the PWL functions for fc0:  18%|█▊        | 47/256 [13:23<51:31, 14.79s/it]
# Fitting the PWL functions for fc0:  19%|█▉        | 48/256 [13:23<51:07, 14.75s/it]
# Fitting the PWL functions for fc0:  19%|█▉        | 48/256 [13:42<51:07, 14.75s/it]
# Fitting the PWL functions for fc0:  19%|█▉        | 48/256 [13:42<51:07, 14.75s/it]
# Fitting the PWL functions for fc0:  19%|█▉        | 49/256 [13:42<55:56, 16.21s/it]
# Fitting the PWL functions for fc0:  19%|█▉        | 49/256 [13:56<55:56, 16.21s/it]
# Fitting the PWL functions for fc0:  19%|█▉        | 49/256 [13:56<55:56, 16.21s/it]
# Fitting the PWL functions for fc0:  20%|█▉        | 50/256 [13:56<53:00, 15.44s/it]
# Fitting the PWL functions for fc0:  20%|█▉        | 50/256 [14:05<53:00, 15.44s/it]
# Fitting the PWL functions for fc0:  20%|█▉        | 50/256 [14:05<53:00, 15.44s/it]
# Fitting the PWL functions for fc0:  20%|█▉        | 51/256 [14:05<46:30, 13.61s/it]
# Fitting the PWL functions for fc0:  20%|█▉        | 51/256 [14:27<46:30, 13.61s/it]
# Fitting the PWL functions for fc0:  20%|█▉        | 51/256 [14:27<46:30, 13.61s/it]
# Fitting the PWL functions for fc0:  20%|██        | 52/256 [14:27<54:57, 16.16s/it]
# Fitting the PWL functions for fc0:  20%|██        | 52/256 [14:45<54:57, 16.16s/it]
# Fitting the PWL functions for fc0:  20%|██        | 52/256 [14:45<54:57, 16.16s/it]
# Fitting the PWL functions for fc0:  21%|██        | 53/256 [14:45<56:17, 16.64s/it]
# Fitting the PWL functions for fc0:  21%|██        | 53/256 [14:58<56:17, 16.64s/it]
# Fitting the PWL functions for fc0:  21%|██        | 53/256 [14:58<56:17, 16.64s/it]
# Fitting the PWL functions for fc0:  21%|██        | 54/256 [14:58<52:25, 15.57s/it]
# Fitting the PWL functions for fc0:  21%|██        | 54/256 [15:12<52:25, 15.57s/it]
# Fitting the PWL functions for fc0:  21%|██        | 54/256 [15:12<52:25, 15.57s/it]
# Fitting the PWL functions for fc0:  21%|██▏       | 55/256 [15:12<50:15, 15.00s/it]
# Fitting the PWL functions for fc0:  21%|██▏       | 55/256 [15:28<50:15, 15.00s/it]
# Fitting the PWL functions for fc0:  21%|██▏       | 55/256 [15:28<50:15, 15.00s/it]
# Fitting the PWL functions for fc0:  22%|██▏       | 56/256 [15:28<51:37, 15.49s/it]
# Fitting the PWL functions for fc0:  22%|██▏       | 56/256 [15:38<51:37, 15.49s/it]
# Fitting the PWL functions for fc0:  22%|██▏       | 56/256 [15:38<51:37, 15.49s/it]
# Fitting the PWL functions for fc0:  22%|██▏       | 57/256 [15:38<45:29, 13.71s/it]
# Fitting the PWL functions for fc0:  22%|██▏       | 57/256 [15:54<45:29, 13.71s/it]
# Fitting the PWL functions for fc0:  22%|██▏       | 57/256 [15:54<45:29, 13.71s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 58/256 [15:54<47:45, 14.47s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 58/256 [16:11<47:45, 14.47s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 58/256 [16:11<47:45, 14.47s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 59/256 [16:11<49:41, 15.13s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 59/256 [16:31<49:41, 15.13s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 59/256 [16:31<49:41, 15.13s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 60/256 [16:31<54:11, 16.59s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 60/256 [16:49<54:11, 16.59s/it]
# Fitting the PWL functions for fc0:  23%|██▎       | 60/256 [16:49<54:11, 16.59s/it]
# Fitting the PWL functions for fc0:  24%|██▍       | 61/256 [16:49<55:23, 17.04s/it]
# Fitting the PWL functions for fc0:  24%|██▍       | 61/256 [17:02<55:23, 17.04s/it]
# Fitting the PWL functions for fc0:  24%|██▍       | 61/256 [17:02<55:23, 17.04s/it]
# Fitting the PWL functions for fc0:  24%|██▍       | 62/256 [17:02<51:23, 15.90s/it]
# Fitting the PWL functions for fc0:  24%|██▍       | 62/256 [17:16<51:23, 15.90s/it]
# Fitting the PWL functions for fc0:  24%|██▍       | 62/256 [17:16<51:23, 15.90s/it]
# Fitting the PWL functions for fc0:  25%|██▍       | 63/256 [17:16<49:00, 15.23s/it]
# Fitting the PWL functions for fc0:  25%|██▍       | 63/256 [17:31<49:00, 15.23s/it]
# Fitting the PWL functions for fc0:  25%|██▍       | 63/256 [17:31<49:00, 15.23s/it]
# Fitting the PWL functions for fc0:  25%|██▌       | 64/256 [17:31<48:33, 15.18s/it]
# Fitting the PWL functions for fc0:  25%|██▌       | 64/256 [17:51<48:33, 15.18s/it]
# Fitting the PWL functions for fc0:  25%|██▌       | 64/256 [17:51<48:33, 15.18s/it]
# Fitting the PWL functions for fc0:  25%|██▌       | 65/256 [17:51<53:19, 16.75s/it]
# Fitting the PWL functions for fc0:  25%|██▌       | 65/256 [18:13<53:19, 16.75s/it]
# Fitting the PWL functions for fc0:  25%|██▌       | 65/256 [18:13<53:19, 16.75s/it]
# Fitting the PWL functions for fc0:  26%|██▌       | 66/256 [18:13<57:46, 18.24s/it]
# Fitting the PWL functions for fc0:  26%|██▌       | 66/256 [18:31<57:46, 18.24s/it]
# Fitting the PWL functions for fc0:  26%|██▌       | 66/256 [18:31<57:46, 18.24s/it]
# Fitting the PWL functions for fc0:  26%|██▌       | 67/256 [18:31<57:19, 18.20s/it]
# Fitting the PWL functions for fc0:  26%|██▌       | 67/256 [18:43<57:19, 18.20s/it]
# Fitting the PWL functions for fc0:  26%|██▌       | 67/256 [18:43<57:19, 18.20s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 68/256 [18:43<50:58, 16.27s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 68/256 [18:58<50:58, 16.27s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 68/256 [18:58<50:58, 16.27s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 69/256 [18:58<49:19, 15.83s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 69/256 [19:15<49:19, 15.83s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 69/256 [19:15<49:19, 15.83s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 70/256 [19:15<50:42, 16.36s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 70/256 [19:31<50:42, 16.36s/it]
# Fitting the PWL functions for fc0:  27%|██▋       | 70/256 [19:31<50:42, 16.36s/it]
# Fitting the PWL functions for fc0:  28%|██▊       | 71/256 [19:31<50:00, 16.22s/it]
# Fitting the PWL functions for fc0:  28%|██▊       | 71/256 [19:49<50:00, 16.22s/it]
# Fitting the PWL functions for fc0:  28%|██▊       | 71/256 [19:49<50:00, 16.22s/it]
# Fitting the PWL functions for fc0:  28%|██▊       | 72/256 [19:49<51:26, 16.77s/it]
# Fitting the PWL functions for fc0:  28%|██▊       | 72/256 [20:07<51:26, 16.77s/it]
# Fitting the PWL functions for fc0:  28%|██▊       | 72/256 [20:07<51:26, 16.77s/it]
# ...
# Fitting the PWL functions for fc2:  77%|███████▋  | 196/256 [48:58<17:00, 17.01s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 196/256 [48:58<17:00, 17.01s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 197/256 [48:58<17:31, 17.83s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 197/256 [49:04<17:31, 17.83s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 197/256 [49:04<17:31, 17.83s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 198/256 [49:04<13:53, 14.37s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 198/256 [49:19<13:53, 14.37s/it]
# Fitting the PWL functions for fc2:  77%|███████▋  | 198/256 [49:19<13:53, 14.37s/it]
# Fitting the PWL functions for fc2:  78%|███████▊  | 199/256 [49:19<13:52, 14.61s/it]
# Fitting the PWL functions for fc2:  78%|███████▊  | 199/256 [49:33<13:52, 14.61s/it]
# Fitting the PWL functions for fc2:  78%|███████▊  | 199/256 [49:33<13:52, 14.61s/it]
# Fitting the PWL functions for fc2:  78%|███████▊  | 200/256 [49:33<13:30, 14.48s/it]
# Fitting the PWL functions for fc2:  78%|███████▊  | 200/256 [49:55<13:30, 14.48s/it]
# Fitting the PWL functions for fc2:  78%|███████▊  | 200/256 [49:55<13:30, 14.48s/it]
# Fitting the PWL functions for fc2:  79%|███████▊  | 201/256 [49:55<15:20, 16.74s/it]
# Fitting the PWL functions for fc2:  79%|███████▊  | 201/256 [50:14<15:20, 16.74s/it]
# Fitting the PWL functions for fc2:  79%|███████▊  | 201/256 [50:14<15:20, 16.74s/it]
# Fitting the PWL functions for fc2:  79%|███████▉  | 202/256 [50:14<15:26, 17.16s/it]
# Fitting the PWL functions for fc2:  79%|███████▉  | 202/256 [50:33<15:26, 17.16s/it]
# Fitting the PWL functions for fc2:  79%|███████▉  | 202/256 [50:33<15:26, 17.16s/it]
# Fitting the PWL functions for fc2:  79%|███████▉  | 203/256 [50:33<15:42, 17.78s/it]
# Fitting the PWL functions for fc2:  79%|███████▉  | 203/256 [50:52<15:42, 17.78s/it]
# Fitting the PWL functions for fc2:  79%|███████▉  | 203/256 [50:52<15:42, 17.78s/it]
# Fitting the PWL functions for fc2:  80%|███████▉  | 204/256 [50:52<15:44, 18.16s/it]
# Fitting the PWL functions for fc2:  80%|███████▉  | 204/256 [51:07<15:44, 18.16s/it]
# Fitting the PWL functions for fc2:  80%|███████▉  | 204/256 [51:07<15:44, 18.16s/it]
# Fitting the PWL functions for fc2:  80%|████████  | 205/256 [51:07<14:42, 17.30s/it]
# Fitting the PWL functions for fc2:  80%|████████  | 205/256 [51:21<14:42, 17.30s/it]
# Fitting the PWL functions for fc2:  80%|████████  | 205/256 [51:21<14:42, 17.30s/it]
# Fitting the PWL functions for fc2:  80%|████████  | 206/256 [51:21<13:25, 16.12s/it]
# Fitting the PWL functions for fc2:  80%|████████  | 206/256 [51:38<13:25, 16.12s/it]
# Fitting the PWL functions for fc2:  80%|████████  | 206/256 [51:38<13:25, 16.12s/it]
# Fitting the PWL functions for fc2:  81%|████████  | 207/256 [51:38<13:35, 16.65s/it]
# Fitting the PWL functions for fc2:  81%|████████  | 207/256 [51:54<13:35, 16.65s/it]
# Fitting the PWL functions for fc2:  81%|████████  | 207/256 [51:54<13:35, 16.65s/it]
# Fitting the PWL functions for fc2:  81%|████████▏ | 208/256 [51:54<13:02, 16.30s/it]
# Fitting the PWL functions for fc2:  81%|████████▏ | 208/256 [52:06<13:02, 16.30s/it]
# Fitting the PWL functions for fc2:  81%|████████▏ | 208/256 [52:06<13:02, 16.30s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 209/256 [52:06<11:45, 15.01s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 209/256 [52:24<11:45, 15.01s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 209/256 [52:24<11:45, 15.01s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 210/256 [52:24<12:07, 15.81s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 210/256 [52:33<12:07, 15.81s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 210/256 [52:33<12:07, 15.81s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 211/256 [52:33<10:22, 13.84s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 211/256 [52:43<10:22, 13.84s/it]
# Fitting the PWL functions for fc2:  82%|████████▏ | 211/256 [52:43<10:22, 13.84s/it]
# Fitting the PWL functions for fc2:  83%|████████▎ | 212/256 [52:43<09:25, 12.85s/it]
# Fitting the PWL functions for fc2:  83%|████████▎ | 212/256 [52:55<09:25, 12.85s/it]
# Fitting the PWL functions for fc2:  83%|████████▎ | 212/256 [52:55<09:25, 12.85s/it]
# Fitting the PWL functions for fc2:  83%|████████▎ | 213/256 [52:55<08:53, 12.40s/it]
# Fitting the PWL functions for fc2:  83%|████████▎ | 213/256 [53:01<08:53, 12.40s/it]
# Fitting the PWL functions for fc2:  83%|████████▎ | 213/256 [53:01<08:53, 12.40s/it]
# Fitting the PWL functions for fc2:  84%|████████▎ | 214/256 [53:01<07:28, 10.68s/it]
# Fitting the PWL functions for fc2:  84%|████████▎ | 214/256 [53:17<07:28, 10.68s/it]
# Fitting the PWL functions for fc2:  84%|████████▎ | 214/256 [53:17<07:28, 10.68s/it]
# Fitting the PWL functions for fc2:  84%|████████▍ | 215/256 [53:17<08:23, 12.29s/it]
# Fitting the PWL functions for fc2:  84%|████████▍ | 215/256 [53:32<08:23, 12.29s/it]
# Fitting the PWL functions for fc2:  84%|████████▍ | 215/256 [53:32<08:23, 12.29s/it]
# Fitting the PWL functions for fc2:  84%|████████▍ | 216/256 [53:32<08:33, 12.84s/it]
# Fitting the PWL functions for fc2:  84%|████████▍ | 216/256 [53:43<08:33, 12.84s/it]
# Fitting the PWL functions for fc2:  84%|████████▍ | 216/256 [53:43<08:33, 12.84s/it]
# Fitting the PWL functions for fc2:  85%|████████▍ | 217/256 [53:43<08:05, 12.46s/it]
# Fitting the PWL functions for fc2:  85%|████████▍ | 217/256 [53:55<08:05, 12.46s/it]
# Fitting the PWL functions for fc2:  85%|████████▍ | 217/256 [53:55<08:05, 12.46s/it]
# Fitting the PWL functions for fc2:  85%|████████▌ | 218/256 [53:55<07:45, 12.24s/it]
# Fitting the PWL functions for fc2:  85%|████████▌ | 218/256 [54:05<07:45, 12.24s/it]
# Fitting the PWL functions for fc2:  85%|████████▌ | 218/256 [54:05<07:45, 12.24s/it]
# Fitting the PWL functions for fc2:  86%|████████▌ | 219/256 [54:05<07:07, 11.56s/it]
# Fitting the PWL functions for fc2:  86%|████████▌ | 219/256 [54:16<07:07, 11.56s/it]
# Fitting the PWL functions for fc2:  86%|████████▌ | 219/256 [54:16<07:07, 11.56s/it]
# Fitting the PWL functions for fc2:  86%|████████▌ | 220/256 [54:16<06:55, 11.53s/it]
# Fitting the PWL functions for fc2:  86%|████████▌ | 220/256 [54:30<06:55, 11.53s/it]
# Fitting the PWL functions for fc2:  86%|████████▌ | 220/256 [54:30<06:55, 11.53s/it]
# Fitting the PWL functions for fc2:  86%|████████▋ | 221/256 [54:30<07:10, 12.29s/it]
# Fitting the PWL functions for fc2:  86%|████████▋ | 221/256 [54:45<07:10, 12.29s/it]
# Fitting the PWL functions for fc2:  86%|████████▋ | 221/256 [54:45<07:10, 12.29s/it]
# Fitting the PWL functions for fc2:  87%|████████▋ | 222/256 [54:45<07:18, 12.90s/it]
# Fitting the PWL functions for fc2:  87%|████████▋ | 222/256 [55:01<07:18, 12.90s/it]
# Fitting the PWL functions for fc2:  87%|████████▋ | 222/256 [55:01<07:18, 12.90s/it]
# Fitting the PWL functions for fc2:  87%|████████▋ | 223/256 [55:01<07:42, 14.03s/it]
# Fitting the PWL functions for fc2:  87%|████████▋ | 223/256 [55:21<07:42, 14.03s/it]
# Fitting the PWL functions for fc2:  87%|████████▋ | 223/256 [55:21<07:42, 14.03s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 224/256 [55:21<08:18, 15.58s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 224/256 [55:37<08:18, 15.58s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 224/256 [55:37<08:18, 15.58s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 225/256 [55:37<08:09, 15.79s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 225/256 [55:52<08:09, 15.79s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 225/256 [55:52<08:09, 15.79s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 226/256 [55:52<07:43, 15.46s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 226/256 [56:01<07:43, 15.46s/it]
# Fitting the PWL functions for fc2:  88%|████████▊ | 226/256 [56:01<07:43, 15.46s/it]
# Fitting the PWL functions for fc2:  89%|████████▊ | 227/256 [56:01<06:39, 13.78s/it]
# Fitting the PWL functions for fc2:  89%|████████▊ | 227/256 [56:13<06:39, 13.78s/it]
# Fitting the PWL functions for fc2:  89%|████████▊ | 227/256 [56:13<06:39, 13.78s/it]
# Fitting the PWL functions for fc2:  89%|████████▉ | 228/256 [56:13<06:06, 13.09s/it]
# Fitting the PWL functions for fc2:  89%|████████▉ | 228/256 [56:32<06:06, 13.09s/it]
# Fitting the PWL functions for fc2:  89%|████████▉ | 228/256 [56:32<06:06, 13.09s/it]
# Fitting the PWL functions for fc2:  89%|████████▉ | 229/256 [56:32<06:42, 14.91s/it]
# Fitting the PWL functions for fc2:  89%|████████▉ | 229/256 [56:40<06:42, 14.91s/it]
# Fitting the PWL functions for fc2:  89%|████████▉ | 229/256 [56:40<06:42, 14.91s/it]
# Fitting the PWL functions for fc2:  90%|████████▉ | 230/256 [56:40<05:33, 12.84s/it]
# Fitting the PWL functions for fc2:  90%|████████▉ | 230/256 [56:53<05:33, 12.84s/it]
# Fitting the PWL functions for fc2:  90%|████████▉ | 230/256 [56:53<05:33, 12.84s/it]
# Fitting the PWL functions for fc2:  90%|█████████ | 231/256 [56:53<05:19, 12.77s/it]
# Fitting the PWL functions for fc2:  90%|█████████ | 231/256 [57:09<05:19, 12.77s/it]
# Fitting the PWL functions for fc2:  90%|█████████ | 231/256 [57:09<05:19, 12.77s/it]
# Fitting the PWL functions for fc2:  91%|█████████ | 232/256 [57:09<05:33, 13.91s/it]
# Fitting the PWL functions for fc2:  91%|█████████ | 232/256 [57:17<05:33, 13.91s/it]
# Fitting the PWL functions for fc2:  91%|█████████ | 232/256 [57:17<05:33, 13.91s/it]
# Fitting the PWL functions for fc2:  91%|█████████ | 233/256 [57:17<04:39, 12.15s/it]
# Fitting the PWL functions for fc2:  91%|█████████ | 233/256 [57:34<04:39, 12.15s/it]
# Fitting the PWL functions for fc2:  91%|█████████ | 233/256 [57:34<04:39, 12.15s/it]
# Fitting the PWL functions for fc2:  91%|█████████▏| 234/256 [57:34<04:58, 13.55s/it]
# Fitting the PWL functions for fc2:  91%|█████████▏| 234/256 [57:48<04:58, 13.55s/it]
# Fitting the PWL functions for fc2:  91%|█████████▏| 234/256 [57:48<04:58, 13.55s/it]
# Fitting the PWL functions for fc2:  92%|█████████▏| 235/256 [57:48<04:45, 13.59s/it]
# Fitting the PWL functions for fc2:  92%|█████████▏| 235/256 [57:59<04:45, 13.59s/it]
# Fitting the PWL functions for fc2:  92%|█████████▏| 235/256 [57:59<04:45, 13.59s/it]
# Fitting the PWL functions for fc2:  92%|█████████▏| 236/256 [57:59<04:17, 12.87s/it]
# Fitting the PWL functions for fc2:  92%|█████████▏| 236/256 [58:17<04:17, 12.87s/it]
# Fitting the PWL functions for fc2:  92%|█████████▏| 236/256 [58:17<04:17, 12.87s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 237/256 [58:17<04:34, 14.44s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 237/256 [58:28<04:34, 14.44s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 237/256 [58:28<04:34, 14.44s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 238/256 [58:28<03:59, 13.33s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 238/256 [58:38<03:59, 13.33s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 238/256 [58:38<03:59, 13.33s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 239/256 [58:38<03:30, 12.39s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 239/256 [58:55<03:30, 12.39s/it]
# Fitting the PWL functions for fc2:  93%|█████████▎| 239/256 [58:55<03:30, 12.39s/it]
# Fitting the PWL functions for fc2:  94%|█████████▍| 240/256 [58:55<03:38, 13.65s/it]
# Fitting the PWL functions for fc2:  94%|█████████▍| 240/256 [59:01<03:38, 13.65s/it]
# Fitting the PWL functions for fc2:  94%|█████████▍| 240/256 [59:01<03:38, 13.65s/it]
# Fitting the PWL functions for fc2:  94%|█████████▍| 241/256 [59:01<02:53, 11.57s/it]
# Fitting the PWL functions for fc2:  94%|█████████▍| 241/256 [59:10<02:53, 11.57s/it]
# Fitting the PWL functions for fc2:  94%|█████████▍| 241/256 [59:10<02:53, 11.57s/it]
# Fitting the PWL functions for fc2:  95%|█████████▍| 242/256 [59:10<02:31, 10.81s/it]
# Fitting the PWL functions for fc2:  95%|█████████▍| 242/256 [59:24<02:31, 10.81s/it]
# Fitting the PWL functions for fc2:  95%|█████████▍| 242/256 [59:24<02:31, 10.81s/it]
# Fitting the PWL functions for fc2:  95%|█████████▍| 243/256 [59:24<02:31, 11.67s/it]
# Fitting the PWL functions for fc2:  95%|█████████▍| 243/256 [59:33<02:31, 11.67s/it]
# Fitting the PWL functions for fc2:  95%|█████████▍| 243/256 [59:33<02:31, 11.67s/it]
# Fitting the PWL functions for fc2:  95%|█████████▌| 244/256 [59:33<02:09, 10.82s/it]
# Fitting the PWL functions for fc2:  95%|█████████▌| 244/256 [59:49<02:09, 10.82s/it]
# Fitting the PWL functions for fc2:  95%|█████████▌| 244/256 [59:49<02:09, 10.82s/it]
# Fitting the PWL functions for fc2:  96%|█████████▌| 245/256 [59:49<02:17, 12.53s/it]
# Fitting the PWL functions for fc2:  96%|█████████▌| 245/256 [59:56<02:17, 12.53s/it]
# Fitting the PWL functions for fc2:  96%|█████████▌| 245/256 [59:56<02:17, 12.53s/it]
# Fitting the PWL functions for fc2:  96%|█████████▌| 246/256 [59:56<01:47, 10.74s/it]
# Fitting the PWL functions for fc2:  96%|█████████▌| 246/256 [1:00:15<01:47, 10.74s/it]
# Fitting the PWL functions for fc2:  96%|█████████▌| 246/256 [1:00:15<01:47, 10.74s/it]
# Fitting the PWL functions for fc2:  96%|█████████▋| 247/256 [1:00:15<02:00, 13.37s/it]
# Fitting the PWL functions for fc2:  96%|█████████▋| 247/256 [1:00:33<02:00, 13.37s/it]
# Fitting the PWL functions for fc2:  96%|█████████▋| 247/256 [1:00:33<02:00, 13.37s/it]
# Fitting the PWL functions for fc2:  97%|█████████▋| 248/256 [1:00:33<01:57, 14.72s/it]
# Fitting the PWL functions for fc2:  97%|█████████▋| 248/256 [1:00:53<01:57, 14.72s/it]
# Fitting the PWL functions for fc2:  97%|█████████▋| 248/256 [1:00:53<01:57, 14.72s/it]
# Fitting the PWL functions for fc2:  97%|█████████▋| 249/256 [1:00:53<01:52, 16.07s/it]
# Fitting the PWL functions for fc2:  97%|█████████▋| 249/256 [1:01:04<01:52, 16.07s/it]
# Fitting the PWL functions for fc2:  97%|█████████▋| 249/256 [1:01:04<01:52, 16.07s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 250/256 [1:01:04<01:28, 14.67s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 250/256 [1:01:13<01:28, 14.67s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 250/256 [1:01:13<01:28, 14.67s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 251/256 [1:01:13<01:04, 12.94s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 251/256 [1:01:24<01:04, 12.94s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 251/256 [1:01:24<01:04, 12.94s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 252/256 [1:01:24<00:49, 12.39s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 252/256 [1:01:34<00:49, 12.39s/it]
# Fitting the PWL functions for fc2:  98%|█████████▊| 252/256 [1:01:34<00:49, 12.39s/it]
# Fitting the PWL functions for fc2:  99%|█████████▉| 253/256 [1:01:34<00:35, 11.84s/it]
# Fitting the PWL functions for fc2:  99%|█████████▉| 253/256 [1:01:49<00:35, 11.84s/it]
# Fitting the PWL functions for fc2:  99%|█████████▉| 253/256 [1:01:49<00:35, 11.84s/it]
# Fitting the PWL functions for fc2:  99%|█████████▉| 254/256 [1:01:49<00:25, 12.56s/it]
# Fitting the PWL functions for fc2:  99%|█████████▉| 254/256 [1:02:02<00:25, 12.56s/it]
# Fitting the PWL functions for fc2:  99%|█████████▉| 254/256 [1:02:02<00:25, 12.56s/it]
# Fitting the PWL functions for fc2: 100%|█████████▉| 255/256 [1:02:02<00:12, 12.88s/it]
# Fitting the PWL functions for fc2: 100%|█████████▉| 255/256 [1:02:15<00:12, 12.88s/it]
# Fitting the PWL functions for fc2: 100%|█████████▉| 255/256 [1:02:15<00:12, 12.88s/it]
# Fitting the PWL functions for fc2: 100%|██████████| 256/256 [1:02:15<00:00, 12.71s/it]
# Fitting the PWL functions for fc2: 100%|██████████| 256/256 [1:02:15<00:00, 14.59s/it]
# Piecewise linear functions created.
# PWLF Test Loss: 4.6236 Accuracy: 0.9823
#
#
# 16-bit Power-of-2 approximated piecewise linear functions created.
# P2 PWLF Test Loss: 4.7357 Accuracy: 0.9820
#
#
# 16-bit Power-of-2 sum approximated piecewise linear functions created.
# P2 PWLF Test Loss: 4.5299 Accuracy: 0.9822
#
#
# 32-bit Power-of-2 approximated piecewise linear functions created.
# P2 PWLF Test Loss: 4.7357 Accuracy: 0.9820
# 32-bit Power-of-2 sum approximated piecewise linear functions created.
# P2 PWLF Test Loss: 4.5774 Accuracy: 0.9821
